# %% [markdown]
# # K-최근접 이웃 (K-Nearest Neighbors, KNN)
# - 분류(Classification)와 회귀(Regression) 를 모두 지원한다.
# - 예측하려는 데이터와 input 데이터들 간의 거리를 측정해 가장 가까운 K개의 데이터셋의 레이블을 참조해 분류/예측한다.
# - 학습시 단순히 input 데이터들을 저장만 하며 예측 시점에 거리를 계산한다.
#     - 학습은 빠르지만 예측시 시간이 많이 걸린다.

# %% [markdown]
# ## 분류
# ![knn1](images/knn-1.png)

# %% [markdown]
# - K-NN에서 **K**는 새로운 데이터포인트를 분류할때 확인할 데이터 포인트의 개수를 지정하는 **하이퍼파라미터**

# %% [markdown]
# ![knn-2](images/knn-2.png)

# %% [markdown]
# - K를 1로 하면 <font color='blue'>파란색</font>, K를 3으로 하면 <font color='orange'>주황색</font> 으로 분류한다.
# - K가 너무 작으면 Overfitting이 일어날 수 있고 K가 너무 크면 Underfitting이 발생할 수 있다.
#     - Overfitting: K값을 더 크게 잡는다.
#     - Underfitting: K값을 더 작게 잡는다.

# %% [markdown]
# ## 주요 하이퍼 파라미터
# - **sklearn.neighbors.KNeighborsClassifier** 사용
# - 이웃 수
#     - n_neighbors = K
#     - **K가 작을 수록 모델이 복잡해져 과대적합이 일어나고 너무 크면 단순해져 성능이 나빠진다.(과소적합)**
#     - n_neighbors는 Feature수의 제곱근 정도를 지정할 때 성능이 좋은 것으로 알려져 있다.
# - 거리 재는 방법
#     - p=2: 유클리디안 거리(Euclidean distance - 기본값 - L2 Norm)
#     - p=1: 맨하탄 거리(Manhattan distance - L1-Norm)

# %% [markdown]
# > ### 유클리디안 거리(Euclidean_distance)
# ![image.png](attachment:image.png)
#
# $$
# distance = \sqrt{(a_1 - b_1)^2 + (a_2-b_2)^2}\\
# n차원 벡터간의 거리 = \sqrt{(a_1 - b_1)^2 + (a_2-b_2)^2 +...+(a_n-b_n)^2}
# $$

# %% [markdown]
# > ### 맨하탄 거리 (Manhattan distance)
# ![image.png](attachment:image.png)
#
# $$
# distance = |a_1 - b_1| + |a_2 - b_2| \\
# 𝑛차원벡터간의거리= |a_1 - b_1| + |a_2 - b_2| + ... + |a_n - b_n|
# $$

# %% [markdown]
# ## 요약
# - K-NN은 이해하기 쉬운 모델이며 튜닝할 하이퍼파라미터의 수가 적어 빠르게 만들 수있다.

# %% [markdown]
# - K-NN은 서비스할 모델을 구현할때 보다는 **복잡한 알고리즘을 적용해 보기 전에 확인용 또는 base line을 잡기 위한 모델로 사용한다.**

# %% [markdown]
# - 훈련세트가 너무 큰 경우(Feature나 관측치의 개수가 많은 경우) 거리를 계산하는 양이 늘어나 예측이 느려진다.
#     - 추론에 시간이 많이 걸린다.

# %% [markdown]
# - Feature간의 값의 단위가 다르면 작은 단위의 Feature에 영향을 많이 받게 되므로 **전처리로 Feature Scaling작업**이 필요하다.

# %% [markdown]
# - Feature가 너무 많은 경우와 대부분의 값이 0으로 구성된(희소-sparse) 데이터셋에서 성능이 아주 나쁘다

# %% [markdown]
# ## 위스콘신 유방암 데이터를 이용한 암환자분류
# ### K값 변화에 따른 성능 변화 확인

# %% [markdown]
# ##### 데이터셋 로드, train/test set 분리

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([212, 357]))

# %% [markdown]
# ##### Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ##### 학습
# - k값 변화에 따른 accuracy의 변화 확인

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

train_acc = []
test_acc = []

k_params = range(1,11) # 1 ~ 10
for k in k_params:
    # 모델 생성
    knn = KNeighborsClassifier(n_neighbors = k)
    
    # 학습
    knn.fit(X_train_scaled, y_train)

    #추론 및 평가
    pred_train = knn.predict(X_train_scaled)
    pred_test = knn.predict(X_test_scaled)
    
    #평가
    train_acc.append(accuracy_score(y_train, pred_train))
    test_acc.append(accuracy_score(y_test, pred_test))

# %% [markdown]
# ##### 결과확인

# %%
train_acc, test_acc
# Out:
# ([1.0,
#   0.9812206572769953,
#   0.9812206572769953,
#   0.9859154929577465,
#   0.9812206572769953,
#   0.9812206572769953,
#   0.9741784037558685,
#   0.9741784037558685,
#   0.9741784037558685,
#   0.9741784037558685],
#  [0.965034965034965,
#   0.958041958041958,
#   0.965034965034965,
#   0.972027972027972,
#   0.965034965034965,
#   0.972027972027972,
#   0.965034965034965,
#   0.972027972027972,
#   0.965034965034965,
#   0.965034965034965])

# %%
df = pd.DataFrame({
    "K":k_params,
    "Train":train_acc,
    "Test": test_acc   
})
df.set_index('K', inplace=True)

# %%
np.sqrt(30)
# Out:
# 5.477225575051661

# %%
df
# Out:
#        Train      Test
# K
# 1   1.000000  0.965035
# 2   0.981221  0.958042
# 3   0.981221  0.965035
# 4   0.985915  0.972028
# 5   0.981221  0.965035
# 6   0.981221  0.972028
# 7   0.974178  0.965035
# 8   0.974178  0.972028
# 9   0.974178  0.965035
# 10  0.974178  0.965035

# %%
import matplotlib.pyplot as plt
df.plot(figsize=(8,6))
plt.show()

# %%
best_model = KNeighborsClassifier(n_neighbors=8)
best_model.fit(X_train_scaled, y_train)
#예측
pred_train = best_model.predict(X_train_scaled)
pred_test = best_model.predict(X_test_scaled)
#평가
print('Train 정확도: ',accuracy_score(y_train, pred_train))
print('Test 정확도: ',accuracy_score(y_test, pred_test))
# Out:
# Train 정확도:  0.9741784037558685
# Test 정확도:  0.972027972027972

# %% [markdown]
# ## GridSearch/Pipline 을 이용해 구현
# - Pipeline을 이용해 전처리기와 모델을 연결한다.
# - GridSearchCV를 이용해 최적의 하이퍼파라미터를 검색한다.

# %% [markdown]
# ##### 데이터셋 로드 및 train/test set 나누기

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report

X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=0)

# %% [markdown]
# ##### Pipeline/GridSearchCV 생성 및 학습

# %%
order = [
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
]
pipeline = Pipeline(order, verbose=True)

param = {
    "knn__n_neighbors":range(1,11), 
    "knn__p":[1,2]
}
gs = GridSearchCV(pipeline, param, scoring='accuracy', cv=5, n_jobs=-1)

gs.fit(X_train, y_train)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'knn__n_neighbors': range(1, 11), 'knn__p': [1, 2]},
#              scoring='accuracy')

# %% [markdown]
# ##### 결과확인

# %%
result_df = pd.DataFrame(gs.cv_results_)
result_df[result_df.columns[6:]].sort_values('rank_test_score').head()
# Out:
#                                    params  split0_test_score  \
# 4    {'knn__n_neighbors': 3, 'knn__p': 1}           0.941860
# 6    {'knn__n_neighbors': 4, 'knn__p': 1}           0.941860
# 5    {'knn__n_neighbors': 3, 'knn__p': 2}           0.965116
# 18  {'knn__n_neighbors': 10, 'knn__p': 1}           0.930233
# 15   {'knn__n_neighbors': 8, 'knn__p': 2}           0.941860
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 4            0.988235           0.988235           0.988235
# 6            0.988235           0.988235           0.988235
# 5            0.976471           0.964706           0.988235
# 18           0.988235           0.976471           0.988235
# 15           0.988235           0.976471           1.000000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 4            0.976471         0.976607        0.017961                1
# 6            0.964706         0.974254        0.018585                2
# 5            0.976471         0.974200        0.008717                3
# 18           0.976471         0.971929        0.021502                4
# 15           0.952941         0.971902        0.021629                5

# %%
gs.best_params_
# Out:
# {'knn__n_neighbors': 3, 'knn__p': 1}

# %% [markdown]
# ##### 최종평가

# %%
best_model = gs.best_estimator_
accuracy_score(y_test, best_model.predict(X_test))
# Out:
# 0.958041958041958

# %%
pred_test = gs.predict(X_test)
accuracy_score(y_test, pred_test)
# Out:
# 0.958041958041958

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94        53
#            1       0.95      0.99      0.97        90
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.95      0.95       143
# weighted avg       0.96      0.96      0.96       143

# %% [markdown]
# # TODO: iris dataset 분류
# - model: KNN 사용
# - gridsearch를 이용해서 최적의 K값 찾는다.

# %% [markdown]
# ##### 데이터셋 로드 및 분리

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report

# %%
X, y = load_iris(return_X_y=True)

# 교차검증(Cross Validation => train/test set)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# ##### Pipeline 생성

# %%
# KNN => Feature scaling이 필요 => Pipeline 묶어준다.
pipeline1 = Pipeline([
    ('s_scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
], verbose=True)

pipeline2 = Pipeline([
    ('mm_scaler', MinMaxScaler()), 
    ('knn', KNeighborsClassifier())
], verbose=True)

# %% [markdown]
# ##### GridSearchCV 생성 및 학습

# %%
params = {
    "knn__n_neighbors":range(1,11),  #k값 1 ~ 10
    "knn__p":[1,2]  # p(거리재는방식): 1-유클리디안, 2-맨하탄
}

# %%
# StandardScaler
gs1 = GridSearchCV(pipeline1,   #모델 (pipeline) 
                   params,      #확인할 하이퍼파라미터들
                   scoring='accuracy', # 검증할 평가지표
                   cv=5, # cross validation시 fold의 개수
                   n_jobs=-1)
# MinMaxScaler
gs2 = GridSearchCV(pipeline2, params, scoring='accuracy', cv=5, n_jobs=-1)

# %%
gs1.fit(X_train, y_train)
# Out:
# [Pipeline] .......... (step 1 of 2) Processing s_scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('s_scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'knn__n_neighbors': range(1, 11), 'knn__p': [1, 2]},
#              scoring='accuracy')

# %%
gs2.fit(X_train, y_train)
# Out:
# [Pipeline] ......... (step 1 of 2) Processing mm_scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('mm_scaler', MinMaxScaler()),
#                                        ('knn', KNeighborsClassifier())],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'knn__n_neighbors': range(1, 11), 'knn__p': [1, 2]},
#              scoring='accuracy')

# %% [markdown]
# ##### 결과 확인

# %%
# StandardScaler -> KNN
print('최고점수:', gs1.best_score_)
print('best parameters:', gs1.best_params_)
# Out:
# 최고점수: 0.9416666666666668
# best parameters: {'knn__n_neighbors': 5, 'knn__p': 1}

# %%
pd.DataFrame(gs1.cv_results_).sort_values('rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8        0.000939      0.000119         0.001451        0.000113
# 10       0.000627      0.000106         0.001077        0.000094
# 11       0.000585      0.000063         0.001060        0.000058
# 13       0.000934      0.000658         0.001095        0.000178
# 9        0.000772      0.000111         0.001260        0.000067
#
#    param_knn__n_neighbors param_knn__p                                params  \
# 8                       5            1  {'knn__n_neighbors': 5, 'knn__p': 1}
# 10                      6            1  {'knn__n_neighbors': 6, 'knn__p': 1}
# 11                      6            2  {'knn__n_neighbors': 6, 'knn__p': 2}
# 13                      7            2  {'knn__n_neighbors': 7, 'knn__p': 2}
# 9                       5            2  {'knn__n_neighbors': 5, 'knn__p': 2}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 8            0.958333           0.958333           0.916667
# 10           0.958333           0.958333           0.916667
# 11           0.916667           0.958333           0.958333
# 13           0.916667           0.958333           0.958333
# 9            0.916667           0.958333           0.916667
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 8            0.958333           0.916667         0.941667        0.020412
# 10           0.958333           0.916667         0.941667        0.020412
# 11           0.958333           0.916667         0.941667        0.020412
# 13           0.958333           0.916667         0.941667        0.020412
# 9            0.958333           0.958333         0.941667        0.020412
#
#     rank_test_score
# 8                 1
# 10                1
# 11                1
# 13                1
# 9                 5

# %%
# MinMaxScaler -> KNN
print('최고점수:', gs2.best_score_)
print('best param:', gs2.best_params_)
# Out:
# 최고점수: 0.9666666666666668
# best param: {'knn__n_neighbors': 4, 'knn__p': 2}

# %%
pd.DataFrame(gs2.cv_results_).sort_values('rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11       0.000400      0.000044         0.000818        0.000042
# 7        0.000789      0.000617         0.001005        0.000260
# 9        0.000438      0.000061         0.000850        0.000050
# 5        0.000719      0.000492         0.000929        0.000080
# 19       0.000421      0.000022         0.000850        0.000015
#
#    param_knn__n_neighbors param_knn__p                                 params  \
# 11                      6            2   {'knn__n_neighbors': 6, 'knn__p': 2}
# 7                       4            2   {'knn__n_neighbors': 4, 'knn__p': 2}
# 9                       5            2   {'knn__n_neighbors': 5, 'knn__p': 2}
# 5                       3            2   {'knn__n_neighbors': 3, 'knn__p': 2}
# 19                     10            2  {'knn__n_neighbors': 10, 'knn__p': 2}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 11                1.0           0.958333           0.958333
# 7                 1.0           0.958333           0.958333
# 9                 1.0           0.958333           0.916667
# 5                 1.0           0.958333           0.958333
# 19                1.0           0.958333           0.916667
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 11           0.958333           0.958333         0.966667        0.016667
# 7            0.958333           0.958333         0.966667        0.016667
# 9            0.958333           0.958333         0.958333        0.026352
# 5            0.958333           0.916667         0.958333        0.026352
# 19           0.958333           0.958333         0.958333        0.026352
#
#     rank_test_score
# 11                1
# 7                 1
# 9                 3
# 5                 3
# 19                3

# %%
best_model = gs2.best_estimator_

# test set으로 최종 평가
acc = accuracy_score(y_test, best_model.predict(X_test))
acc
# Out:
# 0.9666666666666667

# %%
# accuracy(분류) - 모델.score(X, y)
best_model.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
# classification report
result = classification_report(y_test, best_model.predict(X_test))
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
